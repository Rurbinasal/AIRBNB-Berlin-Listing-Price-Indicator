# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import loadtxt
import os, glob
import geopandas as gpd
import geojsonio
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual
import math
from IPython.display import Image
from pandas_profiling import ProfileReport

import plotly
import plotly.express as px
import chart_studio.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
import plotly.graph_objects as go
from plotly.subplots import make_subplots
init_notebook_mode(connected=True)
cf.go_offline()
# %matplotlib inline
#pd.options.plotting.backend = "plotly"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Dashboard
target="price"
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 100)
pd.options.display.max_seq_items = 300
pd.set_option('display.max_colwidth', 150)
sns.set(style="white")

# %%
# Import data_clean
data = pd.read_pickle("saves/data_clean.pkl")

# %% [markdown]
# # Data Exploration

# %%
# Separate/create variables for numerical and categorical features
num_features = list(data.columns[data.dtypes!=object])
cat_features = list(data.columns[data.dtypes==object])
#data_cont = data[num_features]

# %% [markdown]
# ## Interactive Dashboards

# %%
# Display figures from graphical exploration below direcly here in the dashboard
@interact_manual
def show_images(file=os.listdir('data/figures/')):
    display(Image("data/figures/"+file))
# Out:
# interactive(children=(Dropdown(description='file', options=('3_fig1_heatmap.png', 'fig1_heatmap.png', 'fig3_ma…

# %%
# Display table with all rows where feature value is > x (where x is the selected threshold)
@interact(x=widgets.IntSlider(1,0,100,1,continuous_update=False))
def filter_data(column=num_features, x=10):
    return data.loc[data[column]>x]
# Out:
# interactive(children=(Dropdown(description='column', options=('accommodates', 'am_balcony', 'am_breakfast', 'a…

# %%
# Display interactive plot for comparing two features
@interact_manual(x=widgets.Dropdown(options=list(data.select_dtypes('number').columns),index=0,description="Feature"),
                 y=widgets.Dropdown(options=list(data.select_dtypes('number').columns),value=target,description="Target"),
                 kind=widgets.Dropdown(options=["bar", "box", "bubble", "heatmap", "histogram", "scatter"],value="bar",description="Plot Type"))
#                 text='title',
#                 theme=widgets.Dropdown(options=list(cf.themes.THEMES.keys()),description="Theme"),
#                 colorscale=widgets.Dropdown(options=list(cf.colors._scales_names.keys()),description="Colorscale"))


def scatter_plot(x,y, kind):#,theme,colorscale):

    data.iplot(
        kind=kind,
        x=x,
        y=y,
        mode='markers',
        xTitle=str(x),
        yTitle=str(y),
        title=f'{str(y)} vs {str(x)}')
#        text=title,
#        theme=theme,
#        colorscale=colorscale)
# Out:
# interactive(children=(Dropdown(description='Feature', options=('accommodates', 'am_balcony', 'am_breakfast', '…

# %% [markdown]
# ## Tables (non-graphical exploration)

# %%
profile = ProfileReport(data, title='Pandas Profiling Report', explorative=True)
#profile.to_widgets()
profile.to_notebook_iframe()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=69.0, style=ProgressStyle(descrip…
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-3d817b137405> in <module>
#       1 profile = ProfileReport(data, title='Pandas Profiling Report', explorative=True)
#       2 #profile.to_widgets()
# ----> 3 profile.to_notebook_iframe()
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/profile_report.py in to_notebook_iframe(self)
#     387         with warnings.catch_warnings():
#     388             warnings.simplefilter("ignore")
# --> 389             display(get_notebook_iframe(self))
#     390
#     391     def to_widgets(self):
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/report/presentation/flavours/widget/notebook.py in get_notebook_iframe(profile)
#      63         output = get_notebook_iframe_src(profile)
#      64     elif attribute == "srcdoc":
# ---> 65         output = get_notebook_iframe_srcdoc(profile)
#      66     else:
#      67         raise ValueError(
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/report/presentation/flavours/widget/notebook.py in get_notebook_iframe_srcdoc(profile)
#      21     width = config["notebook"]["iframe"]["width"].get(str)
#      22     height = config["notebook"]["iframe"]["height"].get(str)
# ---> 23     src = html.escape(profile.to_html())
#      24
#      25     iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/profile_report.py in to_html(self)
#     357
#     358         """
# --> 359         return self.html
#     360
#     361     def to_json(self) -> str:
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/profile_report.py in html(self)
#     177     def html(self):
#     178         if self._html is None:
# --> 179             self._html = self._render_html()
#     180         return self._html
#     181
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/profile_report.py in _render_html(self)
#     284         from pandas_profiling.report.presentation.flavours import HTMLReport
#     285
# --> 286         report = self.report
#     287
#     288         disable_progress_bar = not config["progress_bar"].get(bool)
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/profile_report.py in report(self)
#     171     def report(self):
#     172         if self._report is None:
# --> 173             self._report = get_report_structure(self.description_set)
#     174         return self._report
#     175
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/profile_report.py in description_set(self)
#     152     def description_set(self):
#     153         if self._description_set is None:
# --> 154             self._description_set = describe_df(self.title, self.df, self._sample)
#     155         return self._description_set
#     156
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/model/describe.py in describe(title, df, sample)
#      94         # Scatter matrix
#      95         pbar.set_postfix_str("Get scatter matrix")
# ---> 96         scatter_matrix = get_scatter_matrix(df, variables)
#      97         pbar.update()
#      98
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/model/summary.py in get_scatter_matrix(df, variables)
#     683             for y in continuous_variables:
#     684                 if x in continuous_variables:
# --> 685                     scatter_matrix[x][y] = scatter_pairwise(df[x], df[y], x, y)
#     686     else:
#     687         scatter_matrix = {}
#
# /opt/anaconda3/envs/nf/lib/python3.6/contextlib.py in inner(*args, **kwds)
#      50         def inner(*args, **kwds):
#      51             with self._recreate_cm():
# ---> 52                 return func(*args, **kwds)
#      53         return inner
#      54
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/visualisation/plot.py in scatter_pairwise(series1, series2, x_label, y_label)
#     271     else:
#     272         plt.scatter(series1.tolist(), series2.tolist(), color=color)
# --> 273     return plot_360_n0sc0pe(plt)
#     274
#     275
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas_profiling/visualisation/utils.py in plot_360_n0sc0pe(plt, image_format, attempts)
#      66             if image_format == "svg":
#      67                 image_str = StringIO()
# ---> 68                 plt.savefig(image_str, format=image_format)
#      69                 image_str.seek(0)
#      70                 result_string = image_str.getvalue()
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     727     if figManager is not None:
#     728         return figManager.canvas.figure
# --> 729     else:
#     730         return figure()
#     731
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178                   frameon=None, metadata=None)
#    2179
# -> 2180         The available output formats depend on the backend being used.
#    2181
#    2182         Parameters
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2021     def get_width_height(self):
#    2022         """
# -> 2023         Return the figure width and height in points or pixels
#    2024         (depending on the backend), truncated to integers.
#    2025         """
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/matplotlib/backend_bases.py in _get_output_canvas(self, fmt)
#    1957             (x, y) pixel positions from left/bottom of the canvas.
#    1958
# -> 1959         Returns
#    1960         -------
#    1961         `~matplotlib.axes.Axes` or None
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/matplotlib/backend_bases.py in get_registered_canvas_class(format)
#     123     An abstract base class to handle drawing/rendering operations.
#     124
# --> 125     The following methods must be implemented in the backend for full
#     126     functionality (though just implementing :meth:`draw_path` alone would
#     127     give a highly capable backend):
#
# /opt/anaconda3/envs/nf/lib/python3.6/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /opt/anaconda3/envs/nf/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /opt/anaconda3/envs/nf/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /opt/anaconda3/envs/nf/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /opt/anaconda3/envs/nf/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /opt/anaconda3/envs/nf/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /opt/anaconda3/envs/nf/lib/python3.6/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /opt/anaconda3/envs/nf/lib/python3.6/site-packages/matplotlib/backends/backend_svg.py in <module>
#      16 import matplotlib as mpl
#      17 from matplotlib import cbook
# ---> 18 from matplotlib.backend_bases import (
#      19      _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      20      RendererBase)
#
# ImportError: cannot import name '_check_savefig_extra_args'

# %%
# Examine shape and head/columns of data
print(data.shape)
data.head(1)
# Out:
# (11059, 54)
#       accommodates  am_balcony  am_breakfast  am_child_friendly  \
# id
# 2015             3         0.0           0.0                1.0
#
#       am_coffee_machine  am_cooking_basics  am_elevator  am_essentials  \
# id
# 2015                1.0                1.0          0.0            1.0
#
#       am_nature_and_views  am_parking  am_pets_allowed  am_private_entrance  \
# id
# 2015                  0.0         1.0              0.0                  0.0
#
#       am_smoking_allowed  am_tv  am_white_goods  \
# id
# 2015                 0.0    1.0             1.0
#
#                                                                                                                                                   amenities  \
# id
# 2015  {TV,"Cable TV",Wifi,Kitchen,Gym,"Free street parking",Heating,"Family/kid friendly","Smoke detector",Essentials,Shampoo,"Lock on bedroom door",Han...
#
#       availability_365  availability_90  bathrooms  bedrooms  beds  \
# id
# 2015               194               15        1.0       1.0   1.0
#
#       calculated_host_listings_count          cancellation_policy  \
# id
# 2015                               6  strict_14_with_grace_period
#
#       cleaning_fee  \
# id
# 2015          30.0
#
#                                                                                                                                                 description  \
# id
# 2015  Great location!  30 of 75 sq meters. This wood floored/high ceiling typical Berlin "Altbau" section of an apartment consists of 1 simple large roo...
#
#       extra_people first_review  guests_included host_identity_verified  \
# id
# 2015          28.0   2016-04-11                1                      t
#
#      host_is_superhost  \
# id
# 2015                 f
#
#                                                                                                                                                 house_rules  \
# id
# 2015  No parties No events No pets No smoking, not even in the courtyard/garden Do not pull the door shut with the keys in the lock from the inside; sho...
#
#      instant_bookable       interaction is_location_exact last_review  \
# id
# 2015                f  Always available                 f  2019-10-12
#
#       latitude  longitude  maximum_nights  minimum_nights  monthly_price  \
# id
# 2015  52.53454   13.40256            1125               4            0.0
#
#                                                   name  \
# id
# 2015  Berlin-Mitte Value! Quiet courtyard/very central
#
#                                                                                                                                       neighborhood_overview  \
# id
# 2015  It is located in the former East Berlin area of Kastanienallee and Zionskirchplatz (Berlins only natural elevation), very charming and original tu...
#
#      neighbourhood  \
# id
# 2015         Mitte
#
#                                                                                   notes  \
# id
# 2015  This is my home, not a hotel. I rent out occasionally when I stay with my friend.
#
#       price property_type  review_scores_rating        room_type  \
# id
# 2015   60.0    Guesthouse                  93.0  Entire home/apt
#
#       security_deposit  \
# id
# 2015             250.0
#
#                                                                                                                                                       space  \
# id
# 2015  A+++ location! This „Einliegerwohnung“ is an extention of a larger apartment with a separate entrance, bathroom and kitchen. The door to the rest ...
#
#                                                                                                                                                     summary  \
# id
# 2015  Great location!  30 of 75 sq meters. This wood floored/high ceiling typical Berlin "Altbau" section of an apartment consists of 1 simple large roo...
#
#                                                                                                                                                     transit  \
# id
# 2015  Close to U-Bahn U8 and U2 (metro), Trams M12, M10 and M8, Busses. Rosenthaler Platz and Hackescher Markt are close by. S-Bahn. Alexander Platz is ...
#
#       weekly_price    zipcode
# id
# 2015           0.0  zip_10119

# %% [markdown]
# **Outliers**

# %%
# Examine illogical column values (e.g. "accommodates" < "guests_included", "bedrooms" > "beds", ...)
data[data.accommodates-data.beds < 0]
# Out:
# Empty DataFrame
# Columns: [accommodates, am_balcony, am_breakfast, am_child_friendly, am_coffee_machine, am_cooking_basics, am_elevator, am_essentials, am_nature_and_views, am_parking, am_pets_allowed, am_private_entrance, am_smoking_allowed, am_tv, am_white_goods, amenities, availability_365, availability_90, bathrooms, bedrooms, beds, calculated_host_listings_count, cancellation_policy, cleaning_fee, description, extra_people, first_review, guests_included, host_identity_verified, host_is_superhost, house_rules, instant_bookable, interaction, is_location_exact, last_review, latitude, longitude, maximum_nights, minimum_nights, monthly_price, name, neighborhood_overview, neighbourhood, notes, price, property_type, review_scores_rating, room_type, security_deposit, space, summary, transit, weekly_price, zipcode]
# Index: []

# %% [markdown]
# **Skew**

# %%
# Look at data skew (to check whether scaling with e.g. log makes sense for highly skewed features)
data.skew()
# Out:
# accommodates                      2.261641
# am_balcony                        1.178853
# am_breakfast                      4.073980
# am_child_friendly                 0.862542
# am_coffee_machine                 0.214839
# am_cooking_basics                -0.119407
# am_elevator                       1.165896
# am_essentials                    -4.615298
# am_nature_and_views               4.771293
# am_parking                       -0.332043
# am_pets_allowed                   1.754742
# am_private_entrance               1.350116
# am_smoking_allowed                2.051961
# am_tv                            -0.067504
# am_white_goods                   -1.649925
# availability_365                  0.791336
# availability_90                   0.315091
# bathrooms                         7.087296
# bedrooms                          2.594074
# beds                              2.930202
# calculated_host_listings_count    5.527483
# cleaning_fee                      1.988979
# extra_people                      2.129496
# guests_included                   3.508553
# latitude                         -0.158447
# longitude                        -0.197266
# maximum_nights                    0.983800
# minimum_nights                    5.433460
# monthly_price                     5.791906
# price                             2.544616
# review_scores_rating             -3.690246
# security_deposit                  6.756624
# weekly_price                      5.107031
# dtype: float64

# %% [markdown]
# Based on skew, log/sqrt shall replace the original feature for:
#
# | **FEATURE** | **METHOD** |
# | :----- | :----- |
# | **accommodates** | log |
# | **bathrooms** | log |
# | **minimum_nights** | log |
# | **price** | log |
# | **review_scores_rating** | sqrt |

# %% [markdown]
# **Correlation**

# %%
# Interactive feature vs. feature correlation check
@interact
def correlations(column1=list(data.select_dtypes('number').columns),
                 column2=list(data.select_dtypes('number').columns)):
    print(f"Correlation: {data[column1].corr(data[column2])}")
# Out:
# interactive(children=(Dropdown(description='column1', options=('accommodates', 'am_balcony', 'am_breakfast', '…

# %%
# Full list of correlation values
data.corr()
# Out:
#                                 accommodates  am_balcony  am_breakfast  \
# accommodates                        1.000000    0.074506     -0.026282
# am_balcony                          0.074506    1.000000     -0.017444
# am_breakfast                       -0.026282   -0.017444      1.000000
# am_child_friendly                   0.308751    0.099631     -0.041059
# am_coffee_machine                   0.155510    0.325279     -0.036960
# am_cooking_basics                   0.112155    0.433160     -0.056616
# am_elevator                         0.049808    0.140129      0.009984
# am_essentials                      -0.032180    0.070987      0.023399
# am_nature_and_views                 0.006167    0.117452     -0.004261
# am_parking                          0.108298    0.237954     -0.028571
# am_pets_allowed                     0.081351    0.017609      0.021428
# am_private_entrance                 0.159074    0.030096      0.004283
# am_smoking_allowed                 -0.100291    0.008763      0.027802
# am_tv                               0.261717    0.108420     -0.028366
# am_white_goods                      0.032696    0.140399      0.005237
# availability_365                    0.167253   -0.036366     -0.014092
# availability_90                     0.109309   -0.022438      0.014496
# bathrooms                           0.278478    0.073209     -0.018277
# bedrooms                            0.702844    0.102930     -0.024921
# beds                                0.822819    0.037552     -0.034024
# calculated_host_listings_count      0.231216   -0.085187     -0.049637
# cleaning_fee                        0.435837    0.113712     -0.049491
# extra_people                        0.257444    0.069912     -0.003597
# guests_included                     0.631271    0.080526     -0.041204
# latitude                            0.015082    0.008879      0.017773
# longitude                           0.010673    0.013115     -0.012767
# maximum_nights                      0.122242   -0.017523     -0.020904
# minimum_nights                     -0.054321   -0.002791     -0.038216
# monthly_price                       0.084346    0.032730     -0.036698
# price                               0.609242    0.134117      0.011122
# review_scores_rating               -0.116754    0.105020      0.025312
# security_deposit                    0.081125    0.075884     -0.022067
# weekly_price                        0.074051    0.045413     -0.042458
#
#                                 am_child_friendly  am_coffee_machine  \
# accommodates                             0.308751           0.155510
# am_balcony                               0.099631           0.325279
# am_breakfast                            -0.041059          -0.036960
# am_child_friendly                        1.000000           0.135224
# am_coffee_machine                        0.135224           1.000000
# am_cooking_basics                        0.117780           0.575187
# am_elevator                              0.024148           0.013504
# am_essentials                           -0.009193           0.093905
# am_nature_and_views                      0.016436           0.083702
# am_parking                               0.195059           0.327122
# am_pets_allowed                          0.069323           0.015506
# am_private_entrance                      0.019146           0.090442
# am_smoking_allowed                      -0.090944          -0.043343
# am_tv                                    0.178406           0.169328
# am_white_goods                           0.038476           0.120777
# availability_365                         0.168445           0.070398
# availability_90                          0.063523           0.052387
# bathrooms                                0.086434           0.052856
# bedrooms                                 0.262904           0.126975
# beds                                     0.283946           0.118024
# calculated_host_listings_count           0.074910           0.051267
# cleaning_fee                             0.228944           0.166438
# extra_people                             0.175812           0.103884
# guests_included                          0.251715           0.160780
# latitude                                 0.005970           0.030548
# longitude                                0.019257          -0.027818
# maximum_nights                           0.020320          -0.006857
# minimum_nights                           0.030946          -0.019849
# monthly_price                            0.187248           0.063398
# price                                    0.229726           0.141819
# review_scores_rating                    -0.035759           0.060494
# security_deposit                         0.066338           0.063034
# weekly_price                             0.197801           0.062358
#
#                                 am_cooking_basics  am_elevator  am_essentials  \
# accommodates                             0.112155     0.049808      -0.032180
# am_balcony                               0.433160     0.140129       0.070987
# am_breakfast                            -0.056616     0.009984       0.023399
# am_child_friendly                        0.117780     0.024148      -0.009193
# am_coffee_machine                        0.575187     0.013504       0.093905
# am_cooking_basics                        1.000000     0.002816       0.125366
# am_elevator                              0.002816     1.000000      -0.016649
# am_essentials                            0.125366    -0.016649       1.000000
# am_nature_and_views                      0.095769     0.027361       0.022891
# am_parking                               0.361338     0.007954       0.109108
# am_pets_allowed                          0.024773    -0.015252       0.010457
# am_private_entrance                      0.064008     0.002702       0.064135
# am_smoking_allowed                      -0.020129    -0.036403       0.016596
# am_tv                                    0.081099     0.150888      -0.021214
# am_white_goods                           0.192303     0.059783       0.041361
# availability_365                        -0.022602     0.030743      -0.050554
# availability_90                         -0.011551     0.037867      -0.034158
# bathrooms                                0.019323     0.099356       0.007735
# bedrooms                                 0.083565     0.029089       0.000983
# beds                                     0.070069     0.018218      -0.012892
# calculated_host_listings_count          -0.102955     0.090597      -0.213497
# cleaning_fee                             0.133617     0.087009       0.011665
# extra_people                             0.113301     0.016316      -0.021269
# guests_included                          0.120464     0.035558       0.000960
# latitude                                 0.008627     0.041294      -0.006298
# longitude                                0.009656    -0.048796       0.009684
# maximum_nights                          -0.007527     0.020812       0.017391
# minimum_nights                          -0.018966     0.044090      -0.020067
# monthly_price                            0.056049     0.029069      -0.038007
# price                                    0.108077     0.183736       0.015737
# review_scores_rating                     0.074109    -0.002919       0.074289
# security_deposit                         0.064528     0.065566       0.018476
# weekly_price                             0.061196     0.030933      -0.043336
#
#                                 am_nature_and_views  am_parking  \
# accommodates                               0.006167    0.108298
# am_balcony                                 0.117452    0.237954
# am_breakfast                              -0.004261   -0.028571
# am_child_friendly                          0.016436    0.195059
# am_coffee_machine                          0.083702    0.327122
# am_cooking_basics                          0.095769    0.361338
# am_elevator                                0.027361    0.007954
# am_essentials                              0.022891    0.109108
# am_nature_and_views                        1.000000    0.105066
# am_parking                                 0.105066    1.000000
# am_pets_allowed                            0.028355    0.042102
# am_private_entrance                        0.042080    0.072343
# am_smoking_allowed                         0.013341   -0.039158
# am_tv                                      0.044695    0.122522
# am_white_goods                             0.007510    0.055208
# availability_365                           0.015391    0.078259
# availability_90                            0.023629    0.073613
# bathrooms                                  0.015129    0.035918
# bedrooms                                   0.001681    0.083651
# beds                                      -0.005474    0.088105
# calculated_host_listings_count            -0.027166   -0.027402
# cleaning_fee                               0.012924    0.097036
# extra_people                               0.019328    0.094886
# guests_included                            0.013708    0.099917
# latitude                                  -0.054615   -0.039319
# longitude                                  0.014136   -0.022455
# maximum_nights                             0.009771   -0.041122
# minimum_nights                            -0.017860   -0.009662
# monthly_price                             -0.010743    0.053452
# price                                     -0.001000    0.059914
# review_scores_rating                       0.010287    0.027681
# security_deposit                           0.013273    0.060059
# weekly_price                              -0.007749    0.058617
#
#                                 am_pets_allowed  am_private_entrance  \
# accommodates                           0.081351             0.159074
# am_balcony                             0.017609             0.030096
# am_breakfast                           0.021428             0.004283
# am_child_friendly                      0.069323             0.019146
# am_coffee_machine                      0.015506             0.090442
# am_cooking_basics                      0.024773             0.064008
# am_elevator                           -0.015252             0.002702
# am_essentials                          0.010457             0.064135
# am_nature_and_views                    0.028355             0.042080
# am_parking                             0.042102             0.072343
# am_pets_allowed                        1.000000             0.012321
# am_private_entrance                    0.012321             1.000000
# am_smoking_allowed                     0.134190            -0.070535
# am_tv                                  0.011913             0.126150
# am_white_goods                         0.026452            -0.059413
# availability_365                       0.046324             0.078068
# availability_90                        0.030736             0.044403
# bathrooms                              0.041983             0.030962
# bedrooms                               0.043110             0.091569
# beds                                   0.056513             0.146170
# calculated_host_listings_count        -0.032997             0.032024
# cleaning_fee                          -0.015226             0.131121
# extra_people                           0.020888             0.022014
# guests_included                        0.039056             0.134043
# latitude                              -0.042147            -0.007163
# longitude                              0.031915             0.005500
# maximum_nights                         0.018991             0.029563
# minimum_nights                        -0.046186            -0.019381
# monthly_price                          0.004123            -0.057163
# price                                  0.020226             0.167752
# review_scores_rating                  -0.023655            -0.022024
# security_deposit                      -0.040505             0.041544
# weekly_price                           0.009448            -0.060982
#
#                                 am_smoking_allowed     am_tv  am_white_goods  \
# accommodates                             -0.100291  0.261717        0.032696
# am_balcony                                0.008763  0.108420        0.140399
# am_breakfast                              0.027802 -0.028366        0.005237
# am_child_friendly                        -0.090944  0.178406        0.038476
# am_coffee_machine                        -0.043343  0.169328        0.120777
# am_cooking_basics                        -0.020129  0.081099        0.192303
# am_elevator                              -0.036403  0.150888        0.059783
# am_essentials                             0.016596 -0.021214        0.041361
# am_nature_and_views                       0.013341  0.044695        0.007510
# am_parking                               -0.039158  0.122522        0.055208
# am_pets_allowed                           0.134190  0.011913        0.026452
# am_private_entrance                      -0.070535  0.126150       -0.059413
# am_smoking_allowed                        1.000000 -0.099792        0.075561
# am_tv                                    -0.099792  1.000000        0.018490
# am_white_goods                            0.075561  0.018490        1.000000
# availability_365                         -0.073305  0.219292       -0.087395
# availability_90                          -0.046424  0.123092       -0.104714
# bathrooms                                -0.030261  0.074363        0.042894
# bedrooms                                 -0.077662  0.169253        0.087841
# beds                                     -0.109506  0.228751       -0.001054
# calculated_host_listings_count           -0.102855  0.194568       -0.050031
# cleaning_fee                             -0.137110  0.233421        0.082727
# extra_people                             -0.036734  0.062563        0.042652
# guests_included                          -0.084942  0.190509        0.020081
# latitude                                 -0.042790  0.046860        0.001058
# longitude                                 0.062241 -0.084688        0.038354
# maximum_nights                           -0.017721  0.061150       -0.016474
# minimum_nights                           -0.039733  0.073955        0.077678
# monthly_price                            -0.052969  0.085810        0.027429
# price                                    -0.126589  0.268270        0.043868
# review_scores_rating                     -0.023857 -0.034944        0.076497
# security_deposit                         -0.069888  0.060251        0.063764
# weekly_price                             -0.039147  0.082788        0.031888
#
#                                 availability_365  availability_90  bathrooms  \
# accommodates                            0.167253         0.109309   0.278478
# am_balcony                             -0.036366        -0.022438   0.073209
# am_breakfast                           -0.014092         0.014496  -0.018277
# am_child_friendly                       0.168445         0.063523   0.086434
# am_coffee_machine                       0.070398         0.052387   0.052856
# am_cooking_basics                      -0.022602        -0.011551   0.019323
# am_elevator                             0.030743         0.037867   0.099356
# am_essentials                          -0.050554        -0.034158   0.007735
# am_nature_and_views                     0.015391         0.023629   0.015129
# am_parking                              0.078259         0.073613   0.035918
# am_pets_allowed                         0.046324         0.030736   0.041983
# am_private_entrance                     0.078068         0.044403   0.030962
# am_smoking_allowed                     -0.073305        -0.046424  -0.030261
# am_tv                                   0.219292         0.123092   0.074363
# am_white_goods                         -0.087395        -0.104714   0.042894
# availability_365                        1.000000         0.632437   0.065774
# availability_90                         0.632437         1.000000   0.044997
# bathrooms                               0.065774         0.044997   1.000000
# bedrooms                                0.074675         0.010832   0.339006
# beds                                    0.190067         0.111708   0.281130
# calculated_host_listings_count          0.223083         0.165951   0.057811
# cleaning_fee                            0.202855         0.075182   0.162503
# extra_people                            0.119574         0.132657   0.077991
# guests_included                         0.121685         0.050413   0.233813
# latitude                               -0.009941        -0.009315  -0.001543
# longitude                              -0.075284        -0.047680  -0.017709
# maximum_nights                          0.104598         0.015664  -0.009017
# minimum_nights                          0.097213        -0.080710  -0.028646
# monthly_price                           0.114072         0.004468   0.048007
# price                                   0.175121         0.157306   0.292879
# review_scores_rating                   -0.125685        -0.114478   0.020584
# security_deposit                        0.085998         0.018583   0.052527
# weekly_price                            0.100220        -0.008494   0.057480
#
#                                 bedrooms      beds  \
# accommodates                    0.702844  0.822819
# am_balcony                      0.102930  0.037552
# am_breakfast                   -0.024921 -0.034024
# am_child_friendly               0.262904  0.283946
# am_coffee_machine               0.126975  0.118024
# am_cooking_basics               0.083565  0.070069
# am_elevator                     0.029089  0.018218
# am_essentials                   0.000983 -0.012892
# am_nature_and_views             0.001681 -0.005474
# am_parking                      0.083651  0.088105
# am_pets_allowed                 0.043110  0.056513
# am_private_entrance             0.091569  0.146170
# am_smoking_allowed             -0.077662 -0.109506
# am_tv                           0.169253  0.228751
# am_white_goods                  0.087841 -0.001054
# availability_365                0.074675  0.190067
# availability_90                 0.010832  0.111708
# bathrooms                       0.339006  0.281130
# bedrooms                        1.000000  0.677041
# beds                            0.677041  1.000000
# calculated_host_listings_count  0.073433  0.199809
# cleaning_fee                    0.389542  0.375729
# extra_people                    0.167570  0.197969
# guests_included                 0.525216  0.554911
# latitude                        0.000903  0.007060
# longitude                       0.001325 -0.002222
# maximum_nights                  0.047211  0.089194
# minimum_nights                 -0.011335 -0.027267
# monthly_price                   0.081830  0.070746
# price                           0.566371  0.506808
# review_scores_rating           -0.013315 -0.123982
# security_deposit                0.095038  0.065961
# weekly_price                    0.098703  0.062482
#
#                                 calculated_host_listings_count  cleaning_fee  \
# accommodates                                          0.231216      0.435837
# am_balcony                                           -0.085187      0.113712
# am_breakfast                                         -0.049637     -0.049491
# am_child_friendly                                     0.074910      0.228944
# am_coffee_machine                                     0.051267      0.166438
# am_cooking_basics                                    -0.102955      0.133617
# am_elevator                                           0.090597      0.087009
# am_essentials                                        -0.213497      0.011665
# am_nature_and_views                                  -0.027166      0.012924
# am_parking                                           -0.027402      0.097036
# am_pets_allowed                                      -0.032997     -0.015226
# am_private_entrance                                   0.032024      0.131121
# am_smoking_allowed                                   -0.102855     -0.137110
# am_tv                                                 0.194568      0.233421
# am_white_goods                                       -0.050031      0.082727
# availability_365                                      0.223083      0.202855
# availability_90                                       0.165951      0.075182
# bathrooms                                             0.057811      0.162503
# bedrooms                                              0.073433      0.389542
# beds                                                  0.199809      0.375729
# calculated_host_listings_count                        1.000000      0.084295
# cleaning_fee                                          0.084295      1.000000
# extra_people                                          0.029433      0.238344
# guests_included                                       0.145899      0.374633
# latitude                                              0.058577      0.028170
# longitude                                            -0.041745     -0.032054
# maximum_nights                                        0.036325      0.103369
# minimum_nights                                        0.030265      0.200985
# monthly_price                                        -0.048248      0.187731
# price                                                 0.094951      0.424752
# review_scores_rating                                 -0.164587     -0.007991
# security_deposit                                      0.024249      0.359960
# weekly_price                                         -0.057914      0.164231
#
#                                 extra_people  guests_included  latitude  \
# accommodates                        0.257444         0.631271  0.015082
# am_balcony                          0.069912         0.080526  0.008879
# am_breakfast                       -0.003597        -0.041204  0.017773
# am_child_friendly                   0.175812         0.251715  0.005970
# am_coffee_machine                   0.103884         0.160780  0.030548
# am_cooking_basics                   0.113301         0.120464  0.008627
# am_elevator                         0.016316         0.035558  0.041294
# am_essentials                      -0.021269         0.000960 -0.006298
# am_nature_and_views                 0.019328         0.013708 -0.054615
# am_parking                          0.094886         0.099917 -0.039319
# am_pets_allowed                     0.020888         0.039056 -0.042147
# am_private_entrance                 0.022014         0.134043 -0.007163
# am_smoking_allowed                 -0.036734        -0.084942 -0.042790
# am_tv                               0.062563         0.190509  0.046860
# am_white_goods                      0.042652         0.020081  0.001058
# availability_365                    0.119574         0.121685 -0.009941
# availability_90                     0.132657         0.050413 -0.009315
# bathrooms                           0.077991         0.233813 -0.001543
# bedrooms                            0.167570         0.525216  0.000903
# beds                                0.197969         0.554911  0.007060
# calculated_host_listings_count      0.029433         0.145899  0.058577
# cleaning_fee                        0.238344         0.374633  0.028170
# extra_people                        1.000000         0.333936  0.002682
# guests_included                     0.333936         1.000000  0.013094
# latitude                            0.002682         0.013094  1.000000
# longitude                           0.004972         0.022230 -0.095886
# maximum_nights                      0.005854         0.102047  0.012854
# minimum_nights                     -0.069291        -0.015134  0.008834
# monthly_price                       0.093621         0.086164  0.001388
# price                               0.165683         0.492901  0.023657
# review_scores_rating               -0.005552        -0.048892 -0.026224
# security_deposit                    0.123650         0.081789  0.005833
# weekly_price                        0.087154         0.085206 -0.007086
#
#                                 longitude  maximum_nights  minimum_nights  \
# accommodates                     0.010673        0.122242       -0.054321
# am_balcony                       0.013115       -0.017523       -0.002791
# am_breakfast                    -0.012767       -0.020904       -0.038216
# am_child_friendly                0.019257        0.020320        0.030946
# am_coffee_machine               -0.027818       -0.006857       -0.019849
# am_cooking_basics                0.009656       -0.007527       -0.018966
# am_elevator                     -0.048796        0.020812        0.044090
# am_essentials                    0.009684        0.017391       -0.020067
# am_nature_and_views              0.014136        0.009771       -0.017860
# am_parking                      -0.022455       -0.041122       -0.009662
# am_pets_allowed                  0.031915        0.018991       -0.046186
# am_private_entrance              0.005500        0.029563       -0.019381
# am_smoking_allowed               0.062241       -0.017721       -0.039733
# am_tv                           -0.084688        0.061150        0.073955
# am_white_goods                   0.038354       -0.016474        0.077678
# availability_365                -0.075284        0.104598        0.097213
# availability_90                 -0.047680        0.015664       -0.080710
# bathrooms                       -0.017709       -0.009017       -0.028646
# bedrooms                         0.001325        0.047211       -0.011335
# beds                            -0.002222        0.089194       -0.027267
# calculated_host_listings_count  -0.041745        0.036325        0.030265
# cleaning_fee                    -0.032054        0.103369        0.200985
# extra_people                     0.004972        0.005854       -0.069291
# guests_included                  0.022230        0.102047       -0.015134
# latitude                        -0.095886        0.012854        0.008834
# longitude                        1.000000       -0.003951       -0.041061
# maximum_nights                  -0.003951        1.000000        0.033528
# minimum_nights                  -0.041061        0.033528        1.000000
# monthly_price                   -0.025734        0.009024        0.100004
# price                           -0.027705        0.113279       -0.045620
# review_scores_rating             0.032468       -0.068926        0.004410
# security_deposit                -0.027865        0.001256        0.243970
# weekly_price                    -0.027113       -0.004836        0.057171
#
#                                 monthly_price     price  review_scores_rating  \
# accommodates                         0.084346  0.609242             -0.116754
# am_balcony                           0.032730  0.134117              0.105020
# am_breakfast                        -0.036698  0.011122              0.025312
# am_child_friendly                    0.187248  0.229726             -0.035759
# am_coffee_machine                    0.063398  0.141819              0.060494
# am_cooking_basics                    0.056049  0.108077              0.074109
# am_elevator                          0.029069  0.183736             -0.002919
# am_essentials                       -0.038007  0.015737              0.074289
# am_nature_and_views                 -0.010743 -0.001000              0.010287
# am_parking                           0.053452  0.059914              0.027681
# am_pets_allowed                      0.004123  0.020226             -0.023655
# am_private_entrance                 -0.057163  0.167752             -0.022024
# am_smoking_allowed                  -0.052969 -0.126589             -0.023857
# am_tv                                0.085810  0.268270             -0.034944
# am_white_goods                       0.027429  0.043868              0.076497
# availability_365                     0.114072  0.175121             -0.125685
# availability_90                      0.004468  0.157306             -0.114478
# bathrooms                            0.048007  0.292879              0.020584
# bedrooms                             0.081830  0.566371             -0.013315
# beds                                 0.070746  0.506808             -0.123982
# calculated_host_listings_count      -0.048248  0.094951             -0.164587
# cleaning_fee                         0.187731  0.424752             -0.007991
# extra_people                         0.093621  0.165683             -0.005552
# guests_included                      0.086164  0.492901             -0.048892
# latitude                             0.001388  0.023657             -0.026224
# longitude                           -0.025734 -0.027705              0.032468
# maximum_nights                       0.009024  0.113279             -0.068926
# minimum_nights                       0.100004 -0.045620              0.004410
# monthly_price                        1.000000  0.127471             -0.003755
# price                                0.127471  1.000000              0.023951
# review_scores_rating                -0.003755  0.023951              1.000000
# security_deposit                     0.100360  0.133942              0.018843
# weekly_price                         0.785820  0.127819              0.007124
#
#                                 security_deposit  weekly_price
# accommodates                            0.081125      0.074051
# am_balcony                              0.075884      0.045413
# am_breakfast                           -0.022067     -0.042458
# am_child_friendly                       0.066338      0.197801
# am_coffee_machine                       0.063034      0.062358
# am_cooking_basics                       0.064528      0.061196
# am_elevator                             0.065566      0.030933
# am_essentials                           0.018476     -0.043336
# am_nature_and_views                     0.013273     -0.007749
# am_parking                              0.060059      0.058617
# am_pets_allowed                        -0.040505      0.009448
# am_private_entrance                     0.041544     -0.060982
# am_smoking_allowed                     -0.069888     -0.039147
# am_tv                                   0.060251      0.082788
# am_white_goods                          0.063764      0.031888
# availability_365                        0.085998      0.100220
# availability_90                         0.018583     -0.008494
# bathrooms                               0.052527      0.057480
# bedrooms                                0.095038      0.098703
# beds                                    0.065961      0.062482
# calculated_host_listings_count          0.024249     -0.057914
# cleaning_fee                            0.359960      0.164231
# extra_people                            0.123650      0.087154
# guests_included                         0.081789      0.085206
# latitude                                0.005833     -0.007086
# longitude                              -0.027865     -0.027113
# maximum_nights                          0.001256     -0.004836
# minimum_nights                          0.243970      0.057171
# monthly_price                           0.100360      0.785820
# price                                   0.133942      0.127819
# review_scores_rating                    0.018843      0.007124
# security_deposit                        1.000000      0.104647
# weekly_price                            0.104647      1.000000

# %% [markdown]
# ## Plot visualizations (graphical exploration)

# %%
# Plot correlation heatmap for numerical features
#Generate a mask for the upper triangle
mask = np.triu(np.ones_like(data[num_features].corr(), dtype=np.bool))

#Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 20))

#Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

#Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(data[num_features].corr(), mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt=".1g");

plt.savefig("data/figures/fig1_heatmap.png")

# %% [markdown]
# Highly correlated features will be removed from the analysis. For this purpose, the threshold is set at two correlations of 0.4 or above. Hence, the following features are removed:
#
# | **FEATURE** | **REASONING** |
# | :----- | :----- |
# | **am_cooking_basics** | Particularly high correlation with **am_coffee_machine** and **am_balcony** |
# | **bedroom** and **beds** | High correlation with each other, with **accommodates** and similar correlation with other features: Combine the two features to one (bed_proxy) |
# | **guests_included** | High correlation with many features |
# | **security_deposit** and **space** | Similar correlation to **cleaning_fee** or **extra_people**: Potentially make a numerical feature counting amount of "special" features instead (0-4) |
# | **** |  |

# %%
# Plot histogram of numerical features
data[num_features].hist(figsize=(20,15));
plt.tight_layout()

# %%
# Plot histogram of skewed feature
data.review_scores_rating.plot(kind='hist', bins=50, figsize=(12,6), facecolor='grey',edgecolor='black');
plt.savefig("data/figures/fig2_histogram_review_scores.png")

# %%
fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
fig.show()
# Out:
# <div>
#
#
#             <div id="0baadf9f-273d-4efb-b685-2e01feb5cf77" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0baadf9f-273d-4efb-b685-2e01feb5cf77")) {
#                     Plotly.newPlot(
#                         '0baadf9f-273d-4efb-b685-2e01feb5cf77',
#                         [{"type": "bar", "y": [2, 3, 1]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
#                         {"respon

# %% [markdown]
# ## Map visualizations (graphical exploration)

# %%
# Display contents of neighbourhoods.geojson visually

# Load up the file
data_2019_12_11_neighb_geojson = gpd.read_file('data/2019-12-11/neighbourhoods.geojson')

# Dropping the redundant column
data_2019_12_11_neighb_geojson.drop('neighbourhood_group', axis=1, inplace=True)

# Creating a dataframe of listing counts and median price by borough
neighbourhood_df = pd.DataFrame(data.groupby('neighbourhood').size())
neighbourhood_df.rename(columns={0: 'number_of_listings'}, inplace=True)
neighbourhood_df['median_price'] = data.groupby('neighbourhood').price.median().values

# Joining the dataframes
neighbourhood_map_df = data_2019_12_11_neighb_geojson.set_index('neighbourhood').join(neighbourhood_df)

# %%
# Plotting the number of listings in each borough
fig1, ax1 = plt.subplots(1, figsize=(15, 6))
neighbourhood_map_df.plot(column='number_of_listings', cmap='Blues', ax=ax1)
ax1.axis('off')
ax1.set_title('Number of Airbnb listings in each Berlin neighbourhood', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=9000))
sm._A = [] # Creates an empty array for the data range
cbar = fig1.colorbar(sm)
plt.savefig("data/figures/fig3_map_listings_neighbourhood.png")

# %%
# Plotting the median price of listings in each borough
fig2, ax2 = plt.subplots(1, figsize=(15, 6))
neighbourhood_map_df.plot(column='median_price', cmap='Blues', ax=ax2)
ax2.axis('off')
ax2.set_title('Median price of Airbnb listings in each Berlin neighbourhood', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=min(neighbourhood_map_df.median_price), vmax=max(neighbourhood_map_df.median_price)))
sm._A = [] # Creates an empty array for the data range
cbar = fig2.colorbar(sm)
plt.savefig("data/figures/fig4_map_median_price_neighbourhood.png")
